# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
import os
print(os.getcwd())
# Out:
# /Users/sa25/Documents/Forest Fires/Forest-Fires/notebooks

# %%
df = pd.read_csv("forestfires.csv")
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df = pd.read_csv("/Users/sa25/Documents/Forest Fires/Forest-Fires/data/forestfires.csv", index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 517 entries, 7 to 6
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       517 non-null    int64
#  1   month   517 non-null    object
#  2   day     517 non-null    object
#  3   FFMC    517 non-null    float64
#  4   DMC     517 non-null    float64
#  5   DC      517 non-null    float64
#  6   ISI     517 non-null    float64
#  7   temp    517 non-null    float64
#  8   RH      517 non-null    int64
#  9   wind    517 non-null    float64
#  10  rain    517 non-null    float64
#  11  area    517 non-null    float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 52.5+ KB

# %%
print(df.index)
# Out:
# Index([7, 7, 7, 8, 8], dtype='int64', name='X')

# %%
print(df.columns)
# Out:
# Index(['Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind',
#        'rain', 'area'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Y      FFMC        DMC          DC       ISI       temp         RH  \
# count  5.0   5.00000   5.000000    5.000000  5.000000   5.000000   5.000000
# mean   5.0  89.68000  37.980000  326.000000  7.420000  12.100000  62.600000
# std    1.0   2.12297   9.714268  321.515941  1.848513   4.219005  33.148152
# min    4.0  86.20000  26.200000   77.500000  5.100000   8.200000  33.000000
# 25%    4.0  89.30000  33.300000   94.300000  6.700000   8.300000  33.000000
# 50%    5.0  90.60000  35.400000  102.200000  6.700000  11.400000  51.000000
# 75%    6.0  90.60000  43.700000  669.100000  9.000000  14.600000  97.000000
# max    6.0  91.70000  51.300000  686.900000  9.600000  18.000000  99.000000
#
#            wind      rain  area
# count  5.000000  5.000000   5.0
# mean   2.940000  0.040000   0.0
# std    2.419297  0.089443   0.0
# min    0.900000  0.000000   0.0
# 25%    1.300000  0.000000   0.0
# 50%    1.800000  0.000000   0.0
# 75%    4.000000  0.000000   0.0
# ...

# %%
"Dataset shape:", df.shape
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 7 to 8
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       5 non-null      int64
#  1   month   5 non-null      object
#  2   day     5 non-null      object
#  3   FFMC    5 non-null      float64
#  4   DMC     5 non-null      float64
#  5   DC      5 non-null      float64
#  6   ISI     5 non-null      float64
#  7   temp    5 non-null      float64
#  8   RH      5 non-null      int64
#  9   wind    5 non-null      float64
#  10  rain    5 non-null      float64
#  11  area    5 non-null      float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 520.0+ bytes
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
df.tail()
# Out:
#    Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# X
# 7  5      0    0  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 7  4      1    3  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 7  4      1    1  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 8  6      0    0  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 8  6      0    2  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df.shape
# Out:
# (5, 12)

# %%
df.dtypes
# Out:
# Y          int64
# month       int8
# day         int8
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# dtype: object

# %%
df.describe()              # Numerical summary
df.describe(include='all') # Include categorical
# Out:
#          Y     month      day      FFMC        DMC          DC       ISI  \
# count  5.0  5.000000  5.00000   5.00000   5.000000    5.000000  5.000000
# mean   5.0  0.400000  1.20000  89.68000  37.980000  326.000000  7.420000
# std    1.0  0.547723  1.30384   2.12297   9.714268  321.515941  1.848513
# min    4.0  0.000000  0.00000  86.20000  26.200000   77.500000  5.100000
# 25%    4.0  0.000000  0.00000  89.30000  33.300000   94.300000  6.700000
# 50%    5.0  0.000000  1.00000  90.60000  35.400000  102.200000  6.700000
# 75%    6.0  1.000000  2.00000  90.60000  43.700000  669.100000  9.000000
# max    6.0  1.000000  3.00000  91.70000  51.300000  686.900000  9.600000
#
#             temp         RH      wind      rain  area
# count   5.000000   5.000000  5.000000  5.000000   5.0
# mean   12.100000  62.600000  2.940000  0.040000   0.0
# std     4.219005  33.148152  2.419297  0.089443   0.0
# min     8.200000  33.000000  0.900000  0.000000   0.0
# ...

# %%
df.isnull().sum()  #check for missing values
# Out:
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
df.duplicated().sum() #check for duplicates
# Out:
# np.int64(0)

# %%
df['month'].value_counts() #check for class imbalance in month column
# Out:
# month
# 0    3
# 1    2
# Name: count, dtype: int64

# %%
df['month'].hist()
plt.show()

# %%
sns.boxplot(x=df['area'])
plt.show()

# %%
df.groupby('month').mean()
# Out:
#               Y       day       FFMC        DMC          DC  ISI  temp  \
# month
# 0      5.666667  0.666667  89.066667  36.933333   91.333333  7.9   9.3
# 1      4.000000  2.000000  90.600000  39.550000  678.000000  6.7  16.3
#
#               RH      wind      rain  area
# month
# 0      82.333333  4.166667  0.066667   0.0
# 1      33.000000  1.100000  0.000000   0.0
